# %%
import pandas as pd
import csv
import json

# %%
base = pd.read_csv("final_base_globe.csv", sep=";")

# %%
base
# Out:
#                                                                                                            final_base_globe
# City                                               Country        Summer..Olympiad. Winter Year latitude          longitude
# Athens                                             Greece         I                 -      1896 39.074207         21.824312
# Paris                                              France         II                -      1900 46.227638          2.213749
# St. Louis                                          United States  III               -      1904 37.090240        -95.712891
# London                                             United Kingdom IV                -      1908 55.378052         -3.435973
# Stockholm                                          Sweden         V                 -      1912 60.128162         18.643501
# ...

# %%
base.insert(loc=5, column = 'latitude', value = '')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/kj/kyj2y6q16_sftfhpvlypk3mm0000gn/T/ipykernel_9000/332791966.py in <module>
# ----> 1 base.insert(loc=5, column = 'latitude', value = '')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    4437
#    4438         value = self._sanitize_column(value)
# -> 4439         self._mgr.insert(loc, column, value)
#    4440
#    4441     def assign(self, **kwargs) -> DataFrame:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value)
#    1228         """
#    1229         # insert to the axis; this could possibly raise a TypeError
# -> 1230         new_axis = self.items.insert(loc, item)
#    1231
#    1232         if value.ndim == 2:
#
# ...

# %%
base
# Out:
#                                   City                            Country  \
# 0                               Athens                             Greece
# 1                                Paris                             France
# 2                            St. Louis                      United States
# 3                               London                     United Kingdom
# 4                            Stockholm                             Sweden
# 5                               Berlin                            Germany
# 6                              Antwerp                            Belgium
# 7                             Chamonix                             France
# 8                                Paris                             France
# 9                           St. Moritz                        Switzerland
# 10                           Amsterdam                        Netherlands
# 11                         Lake Placid                      United States
# ...

# %%
base.insert(loc=6, column = 'longitude', value = '')

# %%
base
# Out:
#                                   City                            Country  \
# 0                               Athens                             Greece
# 1                                Paris                             France
# 2                            St. Louis                      United States
# 3                               London                     United Kingdom
# 4                            Stockholm                             Sweden
# 5                               Berlin                            Germany
# 6                              Antwerp                            Belgium
# 7                             Chamonix                             France
# 8                                Paris                             France
# 9                           St. Moritz                        Switzerland
# 10                           Amsterdam                        Netherlands
# 11                         Lake Placid                      United States
# ...

# %%
base.to_csv(r'final_base_globe.csv', index=False)
